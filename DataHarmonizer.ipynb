# %%
from file_reader import read_excel_files
from report_generator import generate_text_report, generate_small_text_report
from data_analyzer import analyze_data
from data_reorganizer import reorganize_data_merge
from excel_writer import write_excel_file

# %%
dataframes = read_excel_files("input_data")
#for filename, df in dataframes.items():
    #print(filename)
    #print(df
tables_dict = list(dataframes.items())
# Out:
# Lettura di tabelle dei vincoli macchine.xlsx completata.
# Lettura di catalogo_prodotti.xlsx completata.
# Lettura di ordini ricevuti da gestionale.xlsx completata.
# Lettura di dati di produzione.xlsx completata.

# %%
tables = [t[1] for t in tables_dict] 
tables[3]
# Out:
#     received_date              start_date         completion_date  \
# 0      2023-01-01 2023-01-01 00:00:00.000 2023-01-10 15:06:34.063
# 1      2023-01-01 2023-01-01 00:00:00.000 2023-01-03 00:48:27.940
# 2      2023-01-01 2023-01-01 00:00:00.000 2023-01-06 04:48:18.415
# 3      2023-01-03 2023-01-03 00:00:00.000 2023-01-06 21:59:05.051
# 4      2023-01-03 2023-01-03 01:48:27.940 2023-01-10 03:01:07.251
# ..            ...                     ...                     ...
# 695    2023-09-27 2025-05-20 22:39:49.424 2025-06-02 01:30:07.194
# 696    2023-09-27 2025-01-30 16:15:59.904 2025-02-04 03:07:21.300
# 697    2023-09-27 2025-06-02 02:30:07.194 2025-06-05 19:58:58.407
# 698    2023-09-28 2025-06-07 11:14:56.283 2025-06-19 17:28:52.643
# 699    2023-09-28 2025-06-19 18:28:52.643 2025-07-01 01:59:26.950
#
#     shipment_data_required on_time                      customer    press  \
# 0               2023-04-01      si  ACETIFICIO ANDREA MILANO SRL  Press 5
# 1               2023-01-08      si     AMBROSIO VETRI SOC. COOP.  Press 3
# 2               2023-01-08      si                PLASTICHEM SRL  Press 1
# 3               2023-04-03      si         POLIMERI ITALIANI SRL  Press 2
# 4               2023-01-10      no                PLASTICHEM SRL  Press 3
# ..                     ...     ...                           ...      ...
# 695             2023-10-04      no      PLASTICA INDUSTRIALE SRL  Press 1
# 696             2023-10-04      no                CHEMPRODIE SRL  Press 4
# 697             2023-10-27      no               PLASTIMANIA SNC  Press 1
# 698             2023-12-27      no     AMBROSIO VETRI SOC. COOP.  Press 5
# 699             2023-10-28      no  ACETIFICIO ANDREA MILANO SRL  Press 5
#
#      quantity   color size  setup_time  production_time               mazzi  \
# 0          83   Verde  60g    0.500000        76.536487      PP 03-LT.2 60g
# 1          35   Verde  65g    0.500000        15.769254      PP 03-LT.5 65g
# 2          80   Rosso  50g    0.500000        41.101705     ABS 04-LT.1 50g
# 3          48  Giallo  70g    0.500000        30.828245     PET 01-LT.5 70g
# 4         103    Nero  70g    1.108853        55.294787  PE HD 02-LT.10 70g
# ..        ...     ...  ...         ...              ...                 ...
# 695       112   Verde  65g    0.754727        96.191363   PE HD 02-LT.1 65g
# 696        57  Giallo  50g    0.825328        34.793320   PE HD 02-LT.5 50g
# 697        49  Giallo  70g    1.059606        28.767359   PE HD 02-LT.1 70g
# 698       119   Rosso  70g    1.128658        96.948783      PP 03-LT.2 70g
# 699       109   Rosso  50g    1.761801        88.741376     PET 01-LT.2 50g
#
#      material
# 0       PP 03
# 1       PP 03
# 2      ABS 04
# 3      PET 01
# 4    PE HD 02
# ..        ...
# 695  PE HD 02
# 696  PE HD 02
# 697  PE HD 02
# 698     PP 03
# 699    PET 01
#
# [700 rows x 14 columns]

# %%
missing_data = tables[1].isnull().sum()
for column, count in missing_data.items():
    if count > 0:
        print(f"Colonna con dati mancanti: {column}")
        print(f"Numero di dati mancanti: {count}")
# Out:
# Colonna con dati mancanti: product
# Numero di dati mancanti: 25
# Colonna con dati mancanti: color
# Numero di dati mancanti: 59
# Colonna con dati mancanti: size
# Numero di dati mancanti: 51
# Colonna con dati mancanti: material
# Numero di dati mancanti: 3

# %%
for t in tables_dict:
    print(t[0])

Vincoli = tables[0]
Catalogo = tables[1]
Ordini = tables[2]
Produzione = tables[3]

Produzione
# Out:
# tabelle dei vincoli macchine.xlsx
# catalogo_prodotti.xlsx
# ordini ricevuti da gestionale.xlsx
# dati di produzione.xlsx
#     received_date              start_date         completion_date  \
# 0      2023-01-01 2023-01-01 00:00:00.000 2023-01-10 15:06:34.063
# 1      2023-01-01 2023-01-01 00:00:00.000 2023-01-03 00:48:27.940
# 2      2023-01-01 2023-01-01 00:00:00.000 2023-01-06 04:48:18.415
# 3      2023-01-03 2023-01-03 00:00:00.000 2023-01-06 21:59:05.051
# 4      2023-01-03 2023-01-03 01:48:27.940 2023-01-10 03:01:07.251
# ..            ...                     ...                     ...
# 695    2023-09-27 2025-05-20 22:39:49.424 2025-06-02 01:30:07.194
# 696    2023-09-27 2025-01-30 16:15:59.904 2025-02-04 03:07:21.300
# 697    2023-09-27 2025-06-02 02:30:07.194 2025-06-05 19:58:58.407
# 698    2023-09-28 2025-06-07 11:14:56.283 2025-06-19 17:28:52.643
# 699    2023-09-28 2025-06-19 18:28:52.643 2025-07-01 01:59:26.950
#
#     shipment_data_required on_time                      customer    press  \
# 0               2023-04-01      si  ACETIFICIO ANDREA MILANO SRL  Press 5
# 1               2023-01-08      si     AMBROSIO VETRI SOC. COOP.  Press 3
# 2               2023-01-08      si                PLASTICHEM SRL  Press 1
# 3               2023-04-03      si         POLIMERI ITALIANI SRL  Press 2
# 4               2023-01-10      no                PLASTICHEM SRL  Press 3
# ..                     ...     ...                           ...      ...
# 695             2023-10-04      no      PLASTICA INDUSTRIALE SRL  Press 1
# 696             2023-10-04      no                CHEMPRODIE SRL  Press 4
# 697             2023-10-27      no               PLASTIMANIA SNC  Press 1
# 698             2023-12-27      no     AMBROSIO VETRI SOC. COOP.  Press 5
# 699             2023-10-28      no  ACETIFICIO ANDREA MILANO SRL  Press 5
#
#      quantity   color size  setup_time  production_time               mazzi  \
# 0          83   Verde  60g    0.500000        76.536487      PP 03-LT.2 60g
# 1          35   Verde  65g    0.500000        15.769254      PP 03-LT.5 65g
# 2          80   Rosso  50g    0.500000        41.101705     ABS 04-LT.1 50g
# 3          48  Giallo  70g    0.500000        30.828245     PET 01-LT.5 70g
# 4         103    Nero  70g    1.108853        55.294787  PE HD 02-LT.10 70g
# ..        ...     ...  ...         ...              ...                 ...
# 695       112   Verde  65g    0.754727        96.191363   PE HD 02-LT.1 65g
# 696        57  Giallo  50g    0.825328        34.793320   PE HD 02-LT.5 50g
# 697        49  Giallo  70g    1.059606        28.767359   PE HD 02-LT.1 70g
# 698       119   Rosso  70g    1.128658        96.948783      PP 03-LT.2 70g
# 699       109   Rosso  50g    1.761801        88.741376     PET 01-LT.2 50g
#
#      material
# 0       PP 03
# 1       PP 03
# 2      ABS 04
# 3      PET 01
# 4    PE HD 02
# ..        ...
# 695  PE HD 02
# 696  PE HD 02
# 697  PE HD 02
# 698     PP 03
# 699    PET 01
#
# [700 rows x 14 columns]

# %%
display(Ordini)
display(Produzione)
display(Catalogo)
# Out:
#     received_date shipment_date_required             product  material  \
# 0      2023-01-01             2023-04-01      PP 03-LT.2 60g     PP 03
# 1      2023-01-01             2023-01-08      PP 03-LT.5 65g     PP 03
# 2      2023-01-01             2023-01-08     ABS 04-LT.1 50g    ABS 04
# 3      2023-01-03             2023-04-03     PET 01-LT.5 70g    PET 01
# 4      2023-01-03             2023-01-10  PE HD 02-LT.10 70g  PE HD 02
# ..            ...                    ...                 ...       ...
# 695    2023-09-27             2023-10-04   PE HD 02-LT.1 65g  PE HD 02
# 696    2023-09-27             2023-10-04   PE HD 02-LT.5 50g  PE HD 02
# 697    2023-09-27             2023-10-27   PE HD 02-LT.1 70g  PE HD 02
# 698    2023-09-28             2023-12-27      PP 03-LT.2 70g     PP 03
# 699    2023-09-28             2023-10-28     PET 01-LT.2 50g    PET 01
#
#                          customer   color size  quantity
# 0    ACETIFICIO ANDREA MILANO SRL   Verde  60g        83
# 1       AMBROSIO VETRI SOC. COOP.   Verde  65g        35
# 2                  PLASTICHEM SRL   Rosso  50g        80
# 3           POLIMERI ITALIANI SRL  Giallo  70g        48
# 4                  PLASTICHEM SRL    Nero  70g       103
# ..                            ...     ...  ...       ...
# 695      PLASTICA INDUSTRIALE SRL   Verde  65g       112
# 696                CHEMPRODIE SRL  Giallo  50g        57
# 697               PLASTIMANIA SNC  Giallo  70g        49
# 698     AMBROSIO VETRI SOC. COOP.   Rosso  70g       119
# 699  ACETIFICIO ANDREA MILANO SRL   Rosso  50g       109
#
# [700 rows x 8 columns]
#     received_date              start_date         completion_date  \
# 0      2023-01-01 2023-01-01 00:00:00.000 2023-01-10 15:06:34.063
# 1      2023-01-01 2023-01-01 00:00:00.000 2023-01-03 00:48:27.940
# 2      2023-01-01 2023-01-01 00:00:00.000 2023-01-06 04:48:18.415
# 3      2023-01-03 2023-01-03 00:00:00.000 2023-01-06 21:59:05.051
# 4      2023-01-03 2023-01-03 01:48:27.940 2023-01-10 03:01:07.251
# ..            ...                     ...                     ...
# 695    2023-09-27 2025-05-20 22:39:49.424 2025-06-02 01:30:07.194
# 696    2023-09-27 2025-01-30 16:15:59.904 2025-02-04 03:07:21.300
# 697    2023-09-27 2025-06-02 02:30:07.194 2025-06-05 19:58:58.407
# 698    2023-09-28 2025-06-07 11:14:56.283 2025-06-19 17:28:52.643
# 699    2023-09-28 2025-06-19 18:28:52.643 2025-07-01 01:59:26.950
#
#     shipment_data_required on_time                      customer    press  \
# 0               2023-04-01      si  ACETIFICIO ANDREA MILANO SRL  Press 5
# 1               2023-01-08      si     AMBROSIO VETRI SOC. COOP.  Press 3
# 2               2023-01-08      si                PLASTICHEM SRL  Press 1
# 3               2023-04-03      si         POLIMERI ITALIANI SRL  Press 2
# 4               2023-01-10      no                PLASTICHEM SRL  Press 3
# ..                     ...     ...                           ...      ...
# 695             2023-10-04      no      PLASTICA INDUSTRIALE SRL  Press 1
# 696             2023-10-04      no                CHEMPRODIE SRL  Press 4
# 697             2023-10-27      no               PLASTIMANIA SNC  Press 1
# 698             2023-12-27      no     AMBROSIO VETRI SOC. COOP.  Press 5
# 699             2023-10-28      no  ACETIFICIO ANDREA MILANO SRL  Press 5
#
#      quantity   color size  setup_time  production_time               mazzi  \
# 0          83   Verde  60g    0.500000        76.536487      PP 03-LT.2 60g
# 1          35   Verde  65g    0.500000        15.769254      PP 03-LT.5 65g
# 2          80   Rosso  50g    0.500000        41.101705     ABS 04-LT.1 50g
# 3          48  Giallo  70g    0.500000        30.828245     PET 01-LT.5 70g
# 4         103    Nero  70g    1.108853        55.294787  PE HD 02-LT.10 70g
# ..        ...     ...  ...         ...              ...                 ...
# 695       112   Verde  65g    0.754727        96.191363   PE HD 02-LT.1 65g
# 696        57  Giallo  50g    0.825328        34.793320   PE HD 02-LT.5 50g
# 697        49  Giallo  70g    1.059606        28.767359   PE HD 02-LT.1 70g
# 698       119   Rosso  70g    1.128658        96.948783      PP 03-LT.2 70g
# 699       109   Rosso  50g    1.761801        88.741376     PET 01-LT.2 50g
#
#      material
# 0       PP 03
# 1       PP 03
# 2      ABS 04
# 3      PET 01
# 4    PE HD 02
# ..        ...
# 695  PE HD 02
# 696  PE HD 02
# 697  PE HD 02
# 698     PP 03
# 699    PET 01
#
# [700 rows x 14 columns]
#                    product   color size material
# 0    ABS 04-CONT. LT.1 50g   Verde  50g   ABS 04
# 1    ABS 04-CONT. LT.1 50g  Bianco  50g   ABS 04
# 2    ABS 04-CONT. LT.1 50g    Nero  50g   ABS 04
# 3    ABS 04-CONT. LT.1 55g    Nero  55g   ABS 04
# 4    ABS 04-CONT. LT.1 55g   Rosso  55g   ABS 04
# ..                     ...     ...  ...      ...
# 401   PS 05-CONT. LT.5 60g   Verde  60g    PS 05
# 402   PS 05-CONT. LT.5 65g    Nero  65g    PS 05
# 403   PS 05-CONT. LT.5 65g   Rosso  65g    PS 05
# 404   PS 05-CONT. LT.5 70g    Nero  70g    PS 05
# 405   PS 05-CONT. LT.5 70g     Blu  70g    PS 05
#
# [406 rows x 4 columns]

# %%
import pandas as pd

# Supponiamo di avere i dataframe Ordini e Produzione con colonne dai nomi diversi

# Esegui l'INNER JOIN basato su colonne con nomi diversi
join_df = pd.merge(Ordini, Produzione, 
                   left_on=['product', 'customer', 'quantity', 'shipment_date_required', 'received_date'], 
                   right_on=['mazzi', 'customer', 'quantity', 'shipment_data_required', 'received_date'], 
                   how='inner')

# Ora join_df conterrà le righe comuni tra i due dataframe in base alle colonne specificate,
# anche se i nomi delle colonne sono diversi.
colonne_desiderate = ['product', 'quantity', 'Riga', 'Prezzo Univoco', 'Data Consegna', 'Data Richiesta', 'Cliente']
colonne_desiderate = ['product', 'quantity', 'received_date', 'shipment_date_required', 'customer']
join_df
# Out:
#     received_date shipment_date_required             product material_x  \
# 0      2023-01-01             2023-04-01      PP 03-LT.2 60g      PP 03
# 1      2023-01-01             2023-01-08      PP 03-LT.5 65g      PP 03
# 2      2023-01-01             2023-01-08     ABS 04-LT.1 50g     ABS 04
# 3      2023-01-03             2023-04-03     PET 01-LT.5 70g     PET 01
# 4      2023-01-03             2023-01-10  PE HD 02-LT.10 70g   PE HD 02
# ..            ...                    ...                 ...        ...
# 695    2023-09-27             2023-10-04   PE HD 02-LT.1 65g   PE HD 02
# 696    2023-09-27             2023-10-04   PE HD 02-LT.5 50g   PE HD 02
# 697    2023-09-27             2023-10-27   PE HD 02-LT.1 70g   PE HD 02
# 698    2023-09-28             2023-12-27      PP 03-LT.2 70g      PP 03
# 699    2023-09-28             2023-10-28     PET 01-LT.2 50g     PET 01
#
#                          customer color_x size_x  quantity  \
# 0    ACETIFICIO ANDREA MILANO SRL   Verde    60g        83
# 1       AMBROSIO VETRI SOC. COOP.   Verde    65g        35
# 2                  PLASTICHEM SRL   Rosso    50g        80
# 3           POLIMERI ITALIANI SRL  Giallo    70g        48
# 4                  PLASTICHEM SRL    Nero    70g       103
# ..                            ...     ...    ...       ...
# 695      PLASTICA INDUSTRIALE SRL   Verde    65g       112
# 696                CHEMPRODIE SRL  Giallo    50g        57
# 697               PLASTIMANIA SNC  Giallo    70g        49
# 698     AMBROSIO VETRI SOC. COOP.   Rosso    70g       119
# 699  ACETIFICIO ANDREA MILANO SRL   Rosso    50g       109
#
#                  start_date         completion_date shipment_data_required  \
# 0   2023-01-01 00:00:00.000 2023-01-10 15:06:34.063             2023-04-01
# 1   2023-01-01 00:00:00.000 2023-01-03 00:48:27.940             2023-01-08
# 2   2023-01-01 00:00:00.000 2023-01-06 04:48:18.415             2023-01-08
# 3   2023-01-03 00:00:00.000 2023-01-06 21:59:05.051             2023-04-03
# 4   2023-01-03 01:48:27.940 2023-01-10 03:01:07.251             2023-01-10
# ..                      ...                     ...                    ...
# 695 2025-05-20 22:39:49.424 2025-06-02 01:30:07.194             2023-10-04
# 696 2025-01-30 16:15:59.904 2025-02-04 03:07:21.300             2023-10-04
# 697 2025-06-02 02:30:07.194 2025-06-05 19:58:58.407             2023-10-27
# 698 2025-06-07 11:14:56.283 2025-06-19 17:28:52.643             2023-12-27
# 699 2025-06-19 18:28:52.643 2025-07-01 01:59:26.950             2023-10-28
#
#     on_time    press color_y size_y  setup_time  production_time  \
# 0        si  Press 5   Verde    60g    0.500000        76.536487
# 1        si  Press 3   Verde    65g    0.500000        15.769254
# 2        si  Press 1   Rosso    50g    0.500000        41.101705
# 3        si  Press 2  Giallo    70g    0.500000        30.828245
# 4        no  Press 3    Nero    70g    1.108853        55.294787
# ..      ...      ...     ...    ...         ...              ...
# 695      no  Press 1   Verde    65g    0.754727        96.191363
# 696      no  Press 4  Giallo    50g    0.825328        34.793320
# 697      no  Press 1  Giallo    70g    1.059606        28.767359
# 698      no  Press 5   Rosso    70g    1.128658        96.948783
# 699      no  Press 5   Rosso    50g    1.761801        88.741376
#
#                   mazzi material_y
# 0        PP 03-LT.2 60g      PP 03
# 1        PP 03-LT.5 65g      PP 03
# 2       ABS 04-LT.1 50g     ABS 04
# 3       PET 01-LT.5 70g     PET 01
# 4    PE HD 02-LT.10 70g   PE HD 02
# ..                  ...        ...
# 695   PE HD 02-LT.1 65g   PE HD 02
# 696   PE HD 02-LT.5 50g   PE HD 02
# 697   PE HD 02-LT.1 70g   PE HD 02
# 698      PP 03-LT.2 70g      PP 03
# 699     PET 01-LT.2 50g     PET 01
#
# [700 rows x 19 columns]

# %%
join_df[colonne_desiderate]
# Out:
#                 product  quantity received_date shipment_date_required  \
# 0        PP 03-LT.2 60g        83    2023-01-01             2023-04-01
# 1        PP 03-LT.5 65g        35    2023-01-01             2023-01-08
# 2       ABS 04-LT.1 50g        80    2023-01-01             2023-01-08
# 3       PET 01-LT.5 70g        48    2023-01-03             2023-04-03
# 4    PE HD 02-LT.10 70g       103    2023-01-03             2023-01-10
# ..                  ...       ...           ...                    ...
# 695   PE HD 02-LT.1 65g       112    2023-09-27             2023-10-04
# 696   PE HD 02-LT.5 50g        57    2023-09-27             2023-10-04
# 697   PE HD 02-LT.1 70g        49    2023-09-27             2023-10-27
# 698      PP 03-LT.2 70g       119    2023-09-28             2023-12-27
# 699     PET 01-LT.2 50g       109    2023-09-28             2023-10-28
#
#                          customer
# 0    ACETIFICIO ANDREA MILANO SRL
# 1       AMBROSIO VETRI SOC. COOP.
# 2                  PLASTICHEM SRL
# 3           POLIMERI ITALIANI SRL
# 4                  PLASTICHEM SRL
# ..                            ...
# 695      PLASTICA INDUSTRIALE SRL
# 696                CHEMPRODIE SRL
# 697               PLASTIMANIA SNC
# 698     AMBROSIO VETRI SOC. COOP.
# 699  ACETIFICIO ANDREA MILANO SRL
#
# [700 rows x 5 columns]

# %%
import numpy as np

joined = pd.merge(Produzione, Ordini, how='inner')
#lambda x: x.replace('CONT. ', '') if pd.notna(x) else x
#Catalogo['product'] = Catalogo['product'].apply(lambda x: x.replace('CONT. ', '') if np.isnan(x) else x)

#Catalogo['product']
#joined = pd.merge(joined, Catalogo, how='inner')

joined[colonne_desiderate]
#joined
# Out:
#                 product  quantity received_date shipment_date_required  \
# 0        PP 03-LT.2 60g        83    2023-01-01             2023-04-01
# 1        PP 03-LT.5 65g        35    2023-01-01             2023-01-08
# 2       ABS 04-LT.1 50g        80    2023-01-01             2023-01-08
# 3       PET 01-LT.5 70g        48    2023-01-03             2023-04-03
# 4    PE HD 02-LT.10 70g       103    2023-01-03             2023-01-10
# ..                  ...       ...           ...                    ...
# 695   PE HD 02-LT.1 65g       112    2023-09-27             2023-10-04
# 696   PE HD 02-LT.5 50g        57    2023-09-27             2023-10-04
# 697   PE HD 02-LT.1 70g        49    2023-09-27             2023-10-27
# 698      PP 03-LT.2 70g       119    2023-09-28             2023-12-27
# 699     PET 01-LT.2 50g       109    2023-09-28             2023-10-28
#
#                          customer
# 0    ACETIFICIO ANDREA MILANO SRL
# 1       AMBROSIO VETRI SOC. COOP.
# 2                  PLASTICHEM SRL
# 3           POLIMERI ITALIANI SRL
# 4                  PLASTICHEM SRL
# ..                            ...
# 695      PLASTICA INDUSTRIALE SRL
# 696                CHEMPRODIE SRL
# 697               PLASTIMANIA SNC
# 698     AMBROSIO VETRI SOC. COOP.
# 699  ACETIFICIO ANDREA MILANO SRL
#
# [700 rows x 5 columns]

# %%
import pandas as pd

def calculate_similarity(column_df1, column_df2):
    length_unique_df1 = len(set(column_df1))
    length_unique_df2 = len(set(column_df2))

    length_overlap = len(set(column_df1) & set(column_df2))

    overlap_percentage = (length_overlap / min(length_unique_df1, length_unique_df2))

    return overlap_percentage

def similarity(A, B):
    similarity_results = pd.DataFrame(columns=['Colonna1', 'Colonna2', 'Similarita'])

    for col1 in A.columns:
        for col2 in B.columns:
            similarity = calculate_similarity(A[col1], B[col2])
            new_row = {'Colonna1': [col1], 'Colonna2': [col2], 'Similarita': [similarity]}
            new_row = pd.DataFrame(new_row)
            similarity_results = pd.concat([similarity_results, new_row], ignore_index=True)

    groupped = similarity_results.groupby('Colonna1')
    idx =  groupped['Similarita'].idxmax()
    max_scores = similarity_results.loc[idx]

    return max_scores

sim = similarity(Ordini, Produzione)
print("Ordini - Produzione")
display(sim[sim['Similarita']>0.8])
sim = similarity(Produzione, Catalogo)
print("Catalogo - Produzione")
display(sim[sim['Similarita']>0.8])
sim = similarity(Ordini, Catalogo)
print("Catalogo - Ordini")
display(sim[sim['Similarita']>0.8])
# Out:
# Ordini - Produzione
#                    Colonna1                Colonna2  Similarita
# 78                    color                   color         1.0
# 61                 customer                customer         1.0
# 55                 material                material         1.0
# 40                  product                   mazzi         1.0
# 105                quantity                quantity         1.0
# 0             received_date           received_date         1.0
# 17   shipment_date_required  shipment_data_required         1.0
# 93                     size                    size         1.0
# Catalogo - Produzione
#     Colonna1  Colonna2  Similarita
# 55  material  material         1.0
# 38      size      size         1.0
# Catalogo - Ordini
#     Colonna1  Colonna2  Similarita
# 15  material  material         1.0
# 26      size      size         1.0
